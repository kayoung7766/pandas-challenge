# %%
#importing pandas
import pandas as pd

# %%
#load files
school_data="schools_complete.csv"
student_data="students_complete.csv"

#Read files and store in pandas
school_data_df = pd.read_csv(school_data)
student_data_df= pd.read_csv(student_data)

# %%
#merge data files together on school name
complete_school_data=pd.merge(student_data_df, school_data_df, how='left', on=["school_name", "school_name"])

# %%
#checking dataset
complete_school_data.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
#calculating total schools
total_schools=complete_school_data["school_name"].nunique()
total_schools
# Out:
# 15

# %%
#calculating total students
total_students=complete_school_data["student_name"].count()
total_students
# Out:
# 39170

# %%
#calculating total budget 
budget=[]
for x in complete_school_data["budget"]:
    if x not in budget:
        budget.append(x)
budget
type(budget)
total_budget=sum(budget)
total_budget
# Out:
# 24649428

# %%
#average math score
average_math=complete_school_data["math_score"].mean()
average_math
# Out:
# 78.98537145774827

# %%
#average reading score
average_reading=complete_school_data["reading_score"].mean()
average_reading
# Out:
# 81.87784018381414

# %%
# % passing math
#I created a ratio to calculate the average. This way it it able to be recalculated easier for the various groupings
pass_math=[]
for x in complete_school_data["math_score"]:
    if x >=70:
        pass_math.append(100)
    else:
        pass_math.append(0)
complete_school_data ["Pass Math"] =pass_math
pass_math_percent=complete_school_data["Pass Math"].mean()

pass_math_percent
# Out:
# 74.9808526933878

# %%
# % passing reading
#I created a ratio to calculate the average. This way it it able to be recalculated easier for the various groupings
pass_reading=[]
for x in complete_school_data["reading_score"]:
    if x >=70:
        pass_reading.append(100)
    else:
        pass_reading.append(0)
complete_school_data ["Pass Reading"] =pass_reading
pass_reading_percent=complete_school_data["Pass Reading"].mean()

pass_reading_percent
# Out:
# 85.80546336482001

# %%
# % overall pass
#I added up the scores from math and reading. If a student had a 100 in both math and reading,they passed both. The loop changes the scores 
#so it is only 100 and 0 like the previous rations

pass_overall=complete_school_data["Pass Math"] + complete_school_data["Pass Reading"]

    
complete_school_data["Pass Overall"] = pass_overall
complete_school_data.head()
pass_overall_fixed=[]
for x in complete_school_data["Pass Overall"]:
    if x==200:
        pass_overall_fixed.append(100)
    else:
        pass_overall_fixed.append(0)
complete_school_data["Pass Overall"] = pass_overall_fixed
complete_school_data.head()
overall_pass_percent=complete_school_data["Pass Overall"].mean()

overall_pass_percent
# Out:
# 65.17232575950983

# %%
 # Creating summary Table
district_summary = pd.DataFrame({"Total Schools": [total_schools],
                    "Total Students": [total_students],
                    "Total Budget": [total_budget],
                    "Average Math Score": [average_math],
                    "Average Reading Score": [average_reading],
                    "% Passing Math": [pass_math_percent],
                    "% Passing Reading": [pass_reading_percent],
                    "% Overall Passing": [overall_pass_percent]})
district_summary
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %%
# school summary table
#groupby statement
group_school=complete_school_data.groupby(["school_name"])
#calculating average math and reading score, size, budget, pass math,  pass reading, and pass overall
school_df=group_school.mean()
school_df.head()
# Out:
#                       Student ID  reading_score  math_score  School ID  \
# school_name
# Bailey High School       20358.5      81.033963   77.048432        7.0
# Cabrera High School      16941.5      83.975780   83.061895        6.0
# Figueroa High School      4391.0      81.158020   76.711767        1.0
# Ford High School         36165.0      80.746258   77.102592       13.0
# Griffin High School      12995.5      83.816757   83.351499        4.0
#
#                         size     budget  Pass Math  Pass Reading  Pass Overall
# school_name
# Bailey High School    4976.0  3124928.0  66.680064     81.933280     54.642283
# Cabrera High School   1858.0  1081356.0  94.133477     97.039828     91.334769
# Figueroa High School  2949.0  1884411.0  65.988471     80.739234     53.204476
# Ford High School      2739.0  1763916.0  68.309602     79.299014     54.289887
# Griffin High School   1468.0   917500.0  93.392371     97.138965     90.599455

# %%
 
school_df=school_df.rename(columns={'school_name': 'School Name',
                                   "reading_score": "Average Reading Score",
                                    "math_score" : "Average Math Score",
                                    "size": "Total Students",
                                    "budget": "Total School Budget",
                                   "Pass Math": "% Passing Math",
                                   "Pass Reading": "% Passing Reading",
                                   "Pass Overall": "% Overall Passing"})

#adding per student budget 
student_budget=complete_school_data["budget"]/complete_school_data["size"]
student_budget
budget_per_student = []
for x in student_budget:
    if x not in budget_per_student:
        budget_per_student.append(x)
school_df["Per Student Budget"]=budget_per_student
school_df


school_df
#adding school type
names_df=complete_school_data[["school_name", "type"]]
names_df.drop_duplicates(subset ="school_name", 
                      inplace =True)
names_df_sorted=names_df.sort_values("school_name", ascending=True)
names_df_sorted
#school_df["School Type"]=names_df_sorted["type"]
#school_df
#copythe types from the printout to a list
school_type=["District", "Charter", "District", "District", "Charter", "District", "Charter", 
             "District", "District", "Charter", "District", "Charter", "Charter", "Charter", "Charter"]
school_df["School Type"]=school_type
school_df.head()

#dropping unneeded columns
school_df=school_df[["School Type", "Total Students", "Total School Budget", "Per Student Budget", "Average Math Score", "Average Reading Score", "% Passing Math", 
                     "% Passing Reading", "% Overall Passing"]]
school_df
# Out:
# C:\Users\mceky\anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                       School Type  Total Students  Total School Budget  \
# school_name
# Bailey High School       District          4976.0            3124928.0
# Cabrera High School       Charter          1858.0            1081356.0
# Figueroa High School     District          2949.0            1884411.0
# Ford High School         District          2739.0            1763916.0
# Griffin High School       Charter          1468.0             917500.0
# Hernandez High School    District          4635.0            3022020.0
# Holden High School        Charter           427.0             248087.0
# Huang High School        District          2917.0            1910635.0
# ...

# %%
#Top Performing Schools by % Overall Passing
school_df_passing_highest=school_df.sort_values("% Overall Passing", ascending=False)
school_df_passing_highest.iloc[0:5, :]
# Out:
#                     School Type  Total Students  Total School Budget  \
# school_name
# Cabrera High School     Charter          1858.0            1081356.0
# Thomas High School      Charter          1635.0            1043130.0
# Griffin High School     Charter          1468.0             917500.0
# Wilson High School      Charter          2283.0            1319574.0
# Pena High School        Charter           962.0             585858.0
#
#                      Per Student Budget  Average Math Score  \
# school_name
# Cabrera High School               639.0           83.061895
# Thomas High School                650.0           83.418349
# Griffin High School               625.0           83.351499
# Wilson High School                644.0           83.274201
# Pena High School                  609.0           83.839917
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# school_name
# ...

# %%
#Bottom Performing Schools by % Overall Passing
school_df_passing_lowest=school_df.sort_values("% Overall Passing", ascending=True)
school_df_passing_lowest.iloc[0:5, :]
# Out:
#                       School Type  Total Students  Total School Budget  \
# school_name
# Rodriguez High School    District          3999.0            2547363.0
# Figueroa High School     District          2949.0            1884411.0
# Huang High School        District          2917.0            1910635.0
# Hernandez High School    District          4635.0            3022020.0
# Johnson High School      District          4761.0            3094650.0
#
#                        Per Student Budget  Average Math Score  \
# school_name
# Rodriguez High School               583.0           76.842711
# Figueroa High School                600.0           76.711767
# Huang High School                   628.0           76.629414
# Hernandez High School               578.0           77.289752
# Johnson High School                 581.0           77.072464
#
#                        Average Reading Score  % Passing Math  \
# school_name
# ...

# %%
#Math scores by grade
#make a data frame for each grade
nineth=complete_school_data[(complete_school_data["grade"]=="9th")]
nineth
tenth=complete_school_data[(complete_school_data["grade"]=="10th")]
eleventh=complete_school_data[(complete_school_data["grade"]=="11th")]
twelveth=complete_school_data[(complete_school_data["grade"]=="12th")]

# %%
#groupby school and get the average of math score
nineth_group=nineth.groupby("school_name")
nineth_group_average_math=nineth_group.mean()["math_score"]

tenth_group=tenth.groupby("school_name")
tenth_group_average_math=tenth_group.mean()["math_score"]

eleventh_group=eleventh.groupby("school_name")
eleventh_group_average_math=eleventh_group.mean()["math_score"]

twelveth_group=twelveth.groupby("school_name")
twelveth_group_average_math=twelveth_group.mean()["math_score"]
grade_average_math=pd.DataFrame({"9th":nineth_group_average_math, "10th": tenth_group_average_math, "11th": eleventh_group_average_math, "12th": twelveth_group_average_math})
grade_average_math
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %%
#average reading from groupby dataframes
nineth_group_average_reading=nineth_group.mean()["reading_score"]

tenth_group=tenth.groupby("school_name")
tenth_group_average_reading=tenth_group.mean()["reading_score"]

eleventh_group=eleventh.groupby("school_name")
eleventh_group_average_reading=eleventh_group.mean()["reading_score"]

twelveth_group=twelveth.groupby("school_name")
twelveth_group_average_reading=twelveth_group.mean()["reading_score"]
grade_average_reading=pd.DataFrame({"9th":nineth_group_average_reading, "10th": tenth_group_average_reading, "11th": eleventh_group_average_reading, "12th": twelveth_group_average_reading})
grade_average_reading
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %%
#Scores by Budget Per Student
#sorting to get an idea of the bins
school_df_budget=school_df.sort_values("Per Student Budget", ascending=True)
school_df_budget
#Creating the bins
group_names =["$578-600", "$600-629", "$630-649", "650-$655"]
bins = [0, 600, 630, 649, 656]
school_df_budget
school_df_budget["Spending Ranges Per Student"]=pd.cut(school_df_budget["Per Student Budget"], bins, right=False, labels= group_names, include_lowest=True)
school_df_budget

#Groupby
school_df_budget=school_df_budget.groupby("Spending Ranges Per Student")
school_df_budget=school_df_budget.mean()
school_df_budget

#keeping only the relevant columns
school_df_budget=school_df_budget[["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing"]]
school_df_budget
# Out:
#                              Average Math Score  Average Reading Score  \
# Spending Ranges Per Student
# $578-600                              78.752051              81.615120
# $600-629                              80.133149              82.550549
# $630-649                              83.344443              83.911498
# 650-$655                              79.189791              81.876383
#
#                              % Passing Math  % Passing Reading  \
# Spending Ranges Per Student
# $578-600                          72.920741          84.639603
# $600-629                          79.914839          88.785141
# $630-649                          93.800412          96.511302
# 650-$655                          76.087279          86.180387
#
#                              % Overall Passing
# Spending Ranges Per Student
# $578-600                             62.320523
# $600-629                             71.964589
# $630-649                             90.535694
# ...

# %%
#Scores by School Size
school_df_size=school_df.sort_values("Total Students", ascending=True)
school_df_size
group_names=["Small (<1800)", "Medium (1800-2999)", "Large (3000+)"]
bins= [0, 1800, 3000, 5000]
school_df_size["School Size"]=pd.cut(school_df_size["Total Students"], bins, right=False, labels= group_names, include_lowest=True)
school_df_size=school_df_size.groupby("School Size")
school_df_size=school_df_size.mean()
school_df_size=school_df_size[["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing"]]
school_df_size
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (<1800)                83.554500              83.850220       93.526422
# Medium (1800-2999)           80.077015              82.501211       80.219420
# Large (3000+)                77.063340              80.919864       66.464293
#
#                     % Passing Reading  % Overall Passing
# School Size
# Small (<1800)               96.500267          90.241456
# Medium (1800-2999)          88.590875          72.209819
# Large (3000+)               81.059691          53.674303

# %%
#Scores by School Type
type_df=school_df.groupby(["School Type"])
school_type_df=type_df.mean()
school_type_df=school_type_df[["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "% Overall Passing"]]

school_type_df
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.473852              83.896421       93.620830
# District              76.956733              80.966636       66.548453
#
#              % Passing Reading  % Overall Passing
# School Type
# Charter              96.586489          90.432244
# District             80.799062          53.672208

# %%
###Observable trends in in the data
# 1. Small schools consistently have higher scores than medium and large schools. This can be seen across all scores, but is most pronounced in 
# the % overall passing where small scores have 90% overall passing and small schools have 53% overall passing.
 # 2. Charter schools tend to outperform district schools. The average and percent passing scores for charter schools are higher than district 
# schools. This can also be seen in the fact that the top 5 schools in overall passing are all charter schools and the bottom 5 schools in 
# overall passing are district schools.
